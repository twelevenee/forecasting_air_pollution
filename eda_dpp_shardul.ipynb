# %%
import importlib
eda_dpp_utils = importlib.import_module('eda_dpp_utils')
importlib.reload(eda_dpp_utils)

df, df_unnormalised, num_cols, df_unclean = eda_dpp_utils.preProcessing()
# print(df_unnormalised.head())
targets = ['CO(GT)', 'NMHC(GT)', 'C6H6(GT)', 'NOx(GT)', 'NO2(GT)']
eda_dpp_utils.summaryStats(df_unclean)
eda_dpp_utils.summaryStats(df_unnormalised)
eda_dpp_utils.corrHeatmaps(df, targets)
eda_dpp_utils.normalisedTimeSeriesPlots(df, num_cols)
eda_dpp_utils.scatter_targetNontarget(df)
eda_dpp_utils.plot_distribution_fit(df_unnormalised)
# Out:
# +---------------+---------+-----------+----------+----------+-----------+-----------+-----------+----------+
# |               |   count |      mean |      std |      min |       25% |       50% |       75% |      max |
# |---------------+---------+-----------+----------+----------+-----------+-----------+-----------+----------|
# | CO(GT)        |    7674 |    2.1527 |   1.4533 |   0.1    |    1.1    |    1.8    |    2.9    |   11.9   |
# | PT08.S1(CO)   |    8991 | 1099.83   | 217.08   | 647      |  937      | 1063      | 1231      | 2040     |
# | NMHC(GT)      |     914 |  218.812  | 204.46   |   7      |   67      |  150      |  297      | 1189     |
# | C6H6(GT)      |    8991 |   10.0831 |   7.4498 |   0.1    |    4.4    |    8.2    |   14      |   63.7   |
# | PT08.S2(NMHC) |    8991 |  939.153  | 266.831  | 383      |  734.5    |  909      | 1116      | 2214     |
# | NOx(GT)       |    7718 |  246.897  | 212.979  |   2      |   98      |  180      |  326      | 1479     |
# ...
